# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading the dataset to a Pandas DataFrame
df=pd.read_csv("Crop_recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %% [markdown]
# # EDA

# %%
# distribution of Nitrogen value
plt.figure(figsize=(6,6))
sns.distplot(df['N'])
plt.title('Nitrogen Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of Phosphorus value
plt.figure(figsize=(6,6))
sns.distplot(df['P'])
plt.title('Phosphorus Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of temperature value
plt.figure(figsize=(6,6))
sns.distplot(df['temperature'])
plt.title('temperature Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of humidity value
plt.figure(figsize=(6,6))
sns.distplot(df['humidity'])
plt.title('humidity Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of ph value
plt.figure(figsize=(6,6))
sns.distplot(df['ph'])
plt.title('ph Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of rainfall value
plt.figure(figsize=(6,6))
sns.distplot(df['rainfall'])
plt.title('rainfall Distribution')
plt.show()
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# constructing a heatmap to understand the correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cbar=True, square=True,  annot = True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
le=LabelEncoder()
#df['label']=le.fit_transform(df['label'])

# %%
# constructing a heatmap to understand the correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cbar=True, square=True,  annot = True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
#Splitting the Features and Target
X = df.drop(columns='label', axis=1)
y = df[['label']]

# %%
sc=StandardScaler()
#X=sc.fit_transform(X)

# %% [markdown]
# # Train & Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
X_train.shape, X_test.shape,y_train.shape, y_test.shape
# Out:
# ((1650, 7), (550, 7), (1650, 1), (550, 1))

# %% [markdown]
# # Model Fitting

# %%
# Model libraries
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

#Accuracy measuring library
from sklearn.metrics import accuracy_score

# %%
#1. Logistic Regression - used because this model is best suited for binary classification
LR_model = LogisticRegression()

#Fitting training set to the model
LR_model.fit(X_train,y_train)

#Predicting the test set results based on the model
# accuracy on training data
lr_y_pred = LR_model.predict(X_train)
score = accuracy_score(y_train,lr_y_pred)
print('Training Accuracy of LR model is ', score)

# accuracy on testing data
lr_y_pred_test = LR_model.predict(X_test)
score = accuracy_score(y_test,lr_y_pred_test)
print('Testing Accuracy of LR model is ', score)
# Out:
# Training Accuracy of LR model is  0.9775757575757575
# Testing Accuracy of LR model is  0.9436363636363636
# C:\Users\NOMII\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\NOMII\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#2. Support Vector Machine(SVM) 
svm_model = SVC(kernel='linear')

#Fitting training set to the model
svm_model.fit(X_train,y_train)

#Predicting the test set results based on the model
# accuracy on training data
train_svm_y_pred = svm_model.predict(X_train)
score = accuracy_score(y_train,train_svm_y_pred)
print('Training Accuracy of SVM model is ', score)

# accuracy on testing data
test_svm_y_pred = svm_model.predict(X_test)
score = accuracy_score(y_test,test_svm_y_pred)
print('Testing Accuracy of SVM model is ', score)
# Out:
# C:\Users\NOMII\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Training Accuracy of SVM model is  0.9951515151515151
# Testing Accuracy of SVM model is  0.9818181818181818

# %%
#5. Random Forest Classifier 
RFC_model = RandomForestClassifier(random_state=0)

#Fitting training set to the model
RFC_model.fit(X_train, y_train)

#Predicting the test set results based on the model
# accuracy on training data
train_RFC_y_pred = RFC_model.predict(X_train)
score = accuracy_score(y_train,train_RFC_y_pred)
print('Training Accuracy of RFC model is ', score)

# accuracy on testing data
test_RFC_y_pred = RFC_model.predict(X_test)
score = accuracy_score(y_test,test_RFC_y_pred)
print('Testing Accuracy of RFC model is ', score)
# Out:
# C:\Users\NOMII\AppData\Local\Temp/ipykernel_7892/2998808458.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC_model.fit(X_train, y_train)
# Training Accuracy of RFC model is  1.0
# Testing Accuracy of RFC model is  0.9927272727272727

# %%
input_data = (104,18, 30, 23.603016, 60.3, 6.7, 140.91)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = svm_model.predict(input_data_reshaped)
print(prediction)
# Out:
# ['coffee']

# %%
input_data = (59,62,83,18.576659,19.220082,8.104396,72.94940)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = LR_model.predict(input_data_reshaped)
print(prediction)
# Out:
# ['chickpea']

# %%
input_data = (33,58,24,35.45790488,68.75810,5.2695042,108.6333046)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = LR_model.predict(input_data_reshaped)
print(prediction)
# Out:
# ['pigeonpeas']
